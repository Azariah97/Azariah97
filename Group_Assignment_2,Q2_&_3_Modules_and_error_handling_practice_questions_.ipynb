# %% [markdown]
# <a href="https://colab.research.google.com/github/Azariah97/Azariah97/blob/main/Group_Assignment_2%2CQ2_%26_3_Modules_and_error_handling_practice_questions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The total Assignment is marked out of 50

# %% [markdown]
# ## Question 1
#
# A small financial software company is developing a tool to help users calculate loan payments. They need to create a function that calculates the monthly payment for a loan given the principal amount, annual interest rate, and loan term in years. The function should also handle various error cases.
#
# Write a function called `calculate_monthly_payment` that takes the following parameters:
# 1. principal (float): The initial loan amount
# 2. annual_interest_rate (float): The annual interest rate as a percentage
# 3. loan_term_years (int): The loan term in years
#
# The function should return the monthly payment as a float.
#
# Requirements:
# 1. Implement the monthly payment calculation using the formula:
#    monthly_payment = P * (r * (1 + r)^n) / ((1 + r)^n - 1)
#    Where:
#    P = principal
#    r = monthly interest rate (annual rate divided by 12 and converted to decimal)
#    n = total number of months (years * 12)
#
# 2. Handle the following error cases:
#    a. If any of the input parameters are negative, raise a ValueError with an appropriate error message.
#    b. If the annual_interest_rate is 0, use a simple division formula instead: principal / (loan_term_years * 12)
#    c. If the loan_term_years is 0, raise a ValueError with an appropriate error message.
#
# 3. Round the result to 2 decimal places before returning.
#
# 4. Include comments explaining the logic and error handling.
#
#
# Bonus:
# - Implement additional error handling for extremely large input values that might cause overflow errors.

# %%
def calculate_car_insurance_premium(age, free_acc_yrs, car_value, car_type):
  #step 1, error handling
  if age < 16 or age >1 100:
    raise ValueError("Age must be between 16 and 100)")
    if free_acc_yrs < 0 or car_value < 0:
      raise ValueError("Inputs must be non-negative")
 #Step 2, initialize Premium
 premium = 500
 #step 3,

# %%
def calculate_car_insurance_premium(age, years_without_accidents, car_value, car_type=None):
    # Step 1: Error handling
    if age < 16 or age > 100:
        raise ValueError("Age must be between 16 and 100.")
    if years_without_accidents < 0 or car_value < 0:
        raise ValueError("Inputs must be non-negative.")

    # Step 2: Initialize base premium
    premium = 500

    # Step 3: Apply age factor
    if age < 25:
        premium += 100
    elif age >= 40:
        premium -= 50

    # Step 4: Apply driving history factor
    for y in range(min(years_without_accidents, 5)):
        premium *= 0.95

    # Step 5: Apply car value factor
    if car_value >= 20000 and car_value < 50000:
        premium *= 1.05
    elif car_value >= 50000:
        premium *= 1.10

    # Step 6 (Bonus): Apply car type factor (if car_type is provided)
    if car_type == "sports car":
        premium *= 1.20  # Example factor for a sports car
    elif car_type == "SUV":
        premium *= 1.10  # Example factor for an SUV
    elif car_type == "sedan":
        premium *= 1.00  # No additional change for sedan

    # Step 7: Round the final premium
    premium = round(premium, 2)

    return premium

# Step 8: Test cases
# Test case 1: Normal case
# Test case 2: Edge case (young driver, expensive car)
# Test case 3: Error case (invalid input)

# %% [markdown]
# ## Question 2
#
# You work for a car insurance company that wants to create a program to calculate insurance premiums based on various factors. The company needs a function that takes into account the driver's age, driving history, and car value to determine the annual premium.
#
# Task:
# Create a function called `calculate_car_insurance_premium` that calculates the annual car insurance premium based on the following criteria:
#
# 1. Base premium: \$500
# 2. Age factor:
#    - If age < 25: add \$100
#    - If age >= 25 and < 40: no change
#    - If age >= 40: subtract \$50
# 3. Driving history factor:
#    - For each year without accidents (up to 5 years), subtract 5% from the premium
# 4. Car value factor:
#    - If car value < \$20,000: no change
#    - If car value >= \$20,000 and < \$50,000: add 5% to the premium
#    - If car value >= \$50,000: add 10% to the premium
#
# Requirements:
# 1. Implement the `calculate_car_insurance_premium` function that takes the following parameters:
#    - age (int): The driver's age
#    - years_without_accidents (int): Number of years without accidents
#    - car_value (float): The value of the car
#
# 2. Use appropriate control statements (if/elif/else) to apply the factors.
#
# 3. Implement error handling:
#    - Raise a ValueError if any input is negative
#    - Raise a ValueError if the age is less than 16 or greater than 100
#
# 4. Use a loop to calculate the driving history factor.
#
# 5. Round the final premium to 2 decimal places.
#
# 6. Include comments explaining your logic.
#
# 7. Write at least three test cases to demonstrate the function's behavior, including:
#    - A normal case with standard inputs
#    - An edge case (e.g., very young driver with an expensive car)
#    - An error case with invalid inputs
#
# Bonus:
# - Implement an additional factor for the type of car (e.g., sports car, SUV, sedan) that affects the premium.

# %%
def calculate_car_insurance_premium(age, years_without_accidents, car_value, car_type=None):
    # Step 1: Error handling
    if age < 16 or age > 100:
        raise ValueError("Age must be between 16 and 100.")
    if years_without_accidents < 0 or car_value < 0:
        raise ValueError("Inputs must be non-negative.")

    # Step 2: Initialize base premium
    premium = 500

    # Step 3: Apply age factor
    if age < 25:
        premium += 100
    elif age >= 40:
        premium -= 50

    # Step 4: Apply driving history factor
    for y in range(min(years_without_accidents, 5)):
        premium *= 0.95

    # Step 5: Apply car value factor
    if car_value >= 20000 and car_value < 50000:
        premium *= 1.05
    elif car_value >= 50000:
        premium *= 1.10

    # Step 6 (Bonus): Apply car type factor (if car_type is provided)
    if car_type == "sports car":
        premium *= 1.20  # Example factor for a sports car
    elif car_type == "SUV":
        premium *= 1.10  # Example factor for an SUV
    elif car_type == "sedan":
        premium *= 1.00  # No additional change for sedan

    # Step 7: Round the final premium
    premium = round(premium, 2)

    return premium

# Step 8: Test cases
# Test case 1: Normal case
# Test case 2: Edge case (young driver, expensive car)
# Test case 3: Error case (invalid input)

# %% [markdown]
# ## Question 3
#
# A school needs a program to manage student grades for multiple subjects. They want to be able to input grades, calculate averages, and determine if a student passes or fails based on their performance.
#
# Task:
# Create a set of functions to manage student grades and determine their overall performance.
#
# 1. Create a function called `input_grades` that allows a teacher to input grades for a student across multiple subjects.
#
# 2. Create a function called `calculate_average` that calculates the average grade for a student.
#
# 3. Create a function called `determine_pass_fail` that determines if a student passes or fails based on their average grade and individual subject grades.
#
# Requirements:
# 1. Implement the `input_grades` function:
#    - It should use a loop to allow the teacher to input grades for multiple subjects
#    - Each subject should have a name and a grade (0-100)
#    - The function should return a dictionary with subject names as keys and grades as values
#    - Use error handling to ensure grades are within the valid range (0-100)
#
# 2. Implement the `calculate_average` function:
#    - It should take the dictionary of grades as an input
#    - Calculate and return the average grade across all subjects
#    - Use a loop to iterate through the grades
#    - It should return a float
#
# 3. Implement the `determine_pass_fail` function:
#    - It should take the dictionary of grades and the average grade as inputs
#    - A student passes if their average grade is 60 or above AND they have no individual grade below 50
#    - The function should return a boolean (True for pass, False for fail)
#    - Use appropriate control statements to check the conditions
#
# 4. Include comments explaining your logic in each function.
#
# 5. Write at least three test cases to demonstrate the functions' behavior, including:
#    - A case where the student passes
#    - A case where the student fails due to low average
#    - A case where the student fails due to an individual low grade despite a good average
#
# Bonus:
# - Implement a feature to calculate and display the student's letter grade (A, B, C, D, F) based on their average.
# - You can use any grading of your liking.

# %%
def input_grades():
    """
    Allows a teacher to input grades for a student across multiple subjects.
    Returns a dictionary with subject names as keys and grades as values.
    """
    grades = {}  # Initialize an empty dictionary to store subject grades
    while True:
        subject = input("Enter the subject name (or type 'done' to finish): ")
        if subject.lower() == 'done':
            break  # Exit loop if the teacher is done entering grades
        try:
            grade = float(input(f"Enter the grade for {subject}: "))
            if grade < 0 or grade > 100:
                raise ValueError("Grade must be between 0 and 100.")
            grades[subject] = grade
        except ValueError as e:
            print(e)
    return grades

def calculate_average(grades):
    """
    Calculates the average grade for a student.
    Takes a dictionary of grades as input.
    Returns the average grade as a float.
    """
    total = 0  # Initialize total to sum grades
    for grade in grades.values():
        total += grade  # Add each grade to total
    average = total / len(grades)  # Calculate average
    return float(average)  # Return as float

def determine_pass_fail(grades, average):
    """
    Determines if a student passes or fails based on their grades.
    Takes a dictionary of grades and the average grade as inputs.
    Returns True if the student passes, False otherwise.
    """
    if average < 60:  # Check if average grade is below 60
        return False
    for grade in grades.values():
        if grade < 50:  # Check if any individual grade is below 50
            return False
    return True  # Return True if all conditions are met

def calculate_letter_grade(average):
    """
    Calculates the letter grade based on the average.
    Takes the average grade as input.
    Returns the corresponding letter grade.
    """
    if average >= 90:
        return 'A'
    elif average >= 80:
        return 'B'
    elif average >= 70:
        return 'C'
    elif average >= 60:
        return 'D'
    else:
        return 'F'

# Main script
def main():
    # Input grades
    grades = input_grades()

    # Calculate average
    average = calculate_average(grades)
    print(f"Average grade: {average:.2f}")

    # Determine pass or fail
    pass_fail = determine_pass_fail(grades, average)
    if pass_fail:
        print("The student passes.")
    else:
        print("The student fails.")

    # Bonus: Calculate letter grade
    letter_grade = calculate_letter_grade(average)
    print(f"Letter grade: {letter_grade}")

# Run the main function
if __name__ == "__main__":
    main()
